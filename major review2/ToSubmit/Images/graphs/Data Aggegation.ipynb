# %%
# %pip install sqlalchemy
# %pip install pymysql
# %pip install cryptography
# %pip install mysql-connector-python
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/site-packages (2.0.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/site-packages (from sqlalchemy) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/site-packages (from sqlalchemy) (2.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pymysql in /usr/local/lib/python3.10/site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/site-packages (42.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/site-packages (from cryptography) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/site-packages (from cffi>=1.12->cryptography) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/site-packages (8.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Exhaustive Performance

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="ubuntu.sesar.int",
  user="root",
  password="r00t",
  port="3309",
    database="pippo"
)
MAX_NUMBER_OF_NODES = 7
MAX_NUMBER_OF_SERVICES = 7
mycursor = mydb.cursor()

TABLE = "diff_qual_n7_s7_50_80"
#ABLE = "diff_qual_n7_s7_20_100"
FOLDER = "data"

# %% [markdown]
# # Window Time Performance

# %%
mycursor = mydb.cursor()
#result_dict = {}
TTABLE = "qualitative_n7_s7_50_80"
for n in range(3,MAX_NUMBER_OF_NODES+1):
    for w in range(1,n+1):
        query = f"""SELECT number_of_services, number_of_nodes, avg(execution_time)
                FROM {TTABLE}
                WHERE number_of_nodes = {n} AND window_size = {w}
                GROUP BY number_of_nodes, number_of_services,window_size
                ORDER BY number_of_services
            """
        mycursor.execute(query)
        print(query)
        result_dict = {}
        for row in mycursor:
            number_of_services = row[0]
            number_of_nodes = row[1]
            execution_time = row[2]
            # percentage = row[3]

            if number_of_services not in result_dict:
                result_dict[number_of_services] = execution_time
            else:
                result_dict[number_of_services].append(execution_time)
        print(result_dict)
        # Print the formatted output
        with open(f"{FOLDER}/window_time_performance_{TTABLE}_n{n}_w{w}.dat", "w") as file:
            for number_of_nodes, execution_times in result_dict.items():
                # starred = " ".join(map(str, execution_times))
                starred = execution_times
                file.write(f"{number_of_nodes} {starred}\n")
                print(number_of_nodes, starred)
# Out:
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 3 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1140.3481312222223, 3.0: 1439.5125984444444, 4.0: 1718.1798891111112, 5.0: 1907.1671893333332, 6.0: 2097.6584563333336, 7.0: 3531.2613596111105}
# 2.0 1140.3481312222223
# 3.0 1439.5125984444444
# 4.0 1718.1798891111112
# 5.0 1907.1671893333332
# 6.0 2097.6584563333336
# 7.0 3531.2613596111105
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 3 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1204.0619756666665, 3.0: 2314.260784111111, 4.0: 3836.6453623888883, 5.0: 5251.3111815, 6.0: 7619.346685277778, 7.0: 15226.241925388887}
# 2.0 1204.0619756666665
# 3.0 2314.260784111111
# 4.0 3836.6453623888883
# 5.0 5251.3111815
# 6.0 7619.346685277778
# 7.0 15226.241925388887
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 3 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1133.7933473333333, 3.0: 3147.0885041111114, 4.0: 7391.967129277777, 5.0: 12747.966550555555, 6.0: 21051.348225611106, 7.0: 53775.7738593889}
# 2.0 1133.7933473333333
# 3.0 3147.0885041111114
# 4.0 7391.967129277777
# 5.0 12747.966550555555
# 6.0 21051.348225611106
# 7.0 53775.7738593889
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 4 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1458.9045839999999, 3.0: 1813.7414815555555, 4.0: 2382.4743378888893, 5.0: 2366.709591611111, 6.0: 2747.236075944444, 7.0: 4720.550815999999}
# 2.0 1458.9045839999999
# 3.0 1813.7414815555555
# 4.0 2382.4743378888893
# 5.0 2366.709591611111
# 6.0 2747.236075944444
# 7.0 4720.550815999999
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 4 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1639.0756503333332, 3.0: 3380.5725302222218, 4.0: 5772.084641277777, 5.0: 7667.62501111111, 6.0: 11718.293127444447, 7.0: 22865.138661055556}
# 2.0 1639.0756503333332
# 3.0 3380.5725302222218
# 4.0 5772.084641277777
# 5.0 7667.62501111111
# 6.0 11718.293127444447
# 7.0 22865.138661055556
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 4 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1968.8059307777778, 3.0: 6150.863476555554, 4.0: 14463.010338666667, 5.0: 24970.05313661111, 6.0: 41712.908457888894, 7.0: 107754.44292572224}
# 2.0 1968.8059307777778
# 3.0 6150.863476555554
# 4.0 14463.010338666667
# 5.0 24970.05313661111
# 6.0 41712.908457888894
# 7.0 107754.44292572224
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 4 AND window_size = 4
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1902.682194888889, 3.0: 8826.164684111112, 4.0: 27573.123935055555, 5.0: 62371.885255333334, 6.0: 127196.21036783334, 7.0: 370836.8573021111}
# 2.0 1902.682194888889
# 3.0 8826.164684111112
# 4.0 27573.123935055555
# 5.0 62371.885255333334
# 6.0 127196.21036783334
# 7.0 370836.8573021111
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1593.162213, 3.0: 2392.3029793333326, 4.0: 2842.1853273888887, 5.0: 3077.5680470000007, 6.0: 3557.8355497777775, 7.0: 5940.898717055556}
# 2.0 1593.162213
# 3.0 2392.3029793333326
# 4.0 2842.1853273888887
# 5.0 3077.5680470000007
# 6.0 3557.8355497777775
# 7.0 5940.898717055556
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 2067.5680092222224, 3.0: 4203.654026111111, 4.0: 7464.1705282777775, 5.0: 10220.115207277777, 6.0: 14283.312003333333, 7.0: 29214.036507277775}
# 2.0 2067.5680092222224
# 3.0 4203.654026111111
# 4.0 7464.1705282777775
# 5.0 10220.115207277777
# 6.0 14283.312003333333
# 7.0 29214.036507277775
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 2850.8176301111107, 3.0: 8434.489504222223, 4.0: 20563.6087435, 5.0: 36785.69744816666, 6.0: 62916.80802544443, 7.0: 159235.48372094444}
# 2.0 2850.8176301111107
# 3.0 8434.489504222223
# 4.0 20563.6087435
# 5.0 36785.69744816666
# 6.0 62916.80802544443
# 7.0 159235.48372094444
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 4
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 3786.4815411111113, 3.0: 16760.601627444445, 4.0: 56591.67693483332, 5.0: 118742.69103905556, 6.0: 251857.37886194445, 7.0: 737663.3432424446}
# 2.0 3786.4815411111113
# 3.0 16760.601627444445
# 4.0 56591.67693483332
# 5.0 118742.69103905556
# 6.0 251857.37886194445
# 7.0 737663.3432424446
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 5
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 3425.180890444444, 3.0: 27191.21225311111, 4.0: 112496.06383983332, 5.0: 307836.2565478333, 6.0: 757630.6033361667, 7.0: 2582040.378482889}
# 2.0 3425.180890444444
# 3.0 27191.21225311111
# 4.0 112496.06383983332
# 5.0 307836.2565478333
# 6.0 757630.6033361667
# 7.0 2582040.378482889
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 2093.032156888889, 3.0: 2378.023114777777, 4.0: 3297.5127578333336, 5.0: 3905.4602559444443, 6.0: 4152.291502055556, 7.0: 7269.628484777777}
# 2.0 2093.032156888889
# 3.0 2378.023114777777
# 4.0 3297.5127578333336
# 5.0 3905.4602559444443
# 6.0 4152.291502055556
# 7.0 7269.628484777777
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 2799.8023104444446, 3.0: 5332.198060555555, 4.0: 8590.195840666665, 5.0: 12756.528334499999, 6.0: 18406.026610888894, 7.0: 38182.04821683333}
# 2.0 2799.8023104444446
# 3.0 5332.198060555555
# 4.0 8590.195840666665
# 5.0 12756.528334499999
# 6.0 18406.026610888894
# 7.0 38182.04821683333
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 3973.477089222223, 3.0: 10455.451721428572, 4.0: 27018.88768005555, 5.0: 47779.88476844445, 6.0: 83075.88570977777, 7.0: 214022.43086955554}
# 2.0 3973.477089222223
# 3.0 10455.451721428572
# 4.0 27018.88768005555
# 5.0 47779.88476844445
# 6.0 83075.88570977777
# 7.0 214022.43086955554
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 4
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 6200.867156999999, 3.0: 25353.202434222218, 4.0: 81112.88185877778, 5.0: 181041.62535772222, 6.0: 375218.2907187778, 7.0: 1130956.996280278}
# 2.0 6200.867156999999
# 3.0 25353.202434222218
# 4.0 81112.88185877778
# 5.0 181041.62535772222
# 6.0 375218.2907187778
# 7.0 1130956.996280278
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 5
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 11021.595138555558, 3.0: 57008.21291227777, 4.0: 221054.38266444442, 5.0: 601854.5390417223, 6.0: 1502352.8656462224, 7.0: 5368578.490633944}
# 2.0 11021.595138555558
# 3.0 57008.21291227777
# 4.0 221054.38266444442
# 5.0 601854.5390417223
# 6.0 1502352.8656462224
# 7.0 5368578.490633944
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 6
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 11603.912923777776, 3.0: 80932.1727966111, 4.0: 439678.4054553334, 5.0: 1545698.5831309997, 6.0: 4560587.134515945, 7.0: 19626255.963933628}
# 2.0 11603.912923777776
# 3.0 80932.1727966111
# 4.0 439678.4054553334
# 5.0 1545698.5831309997
# 6.0 4560587.134515945
# 7.0 19626255.963933628
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 2704.551385222222, 3.0: 3175.2459733333335, 4.0: 3623.4367573888894, 5.0: 4192.5312766666675, 6.0: 4375.607706944445, 7.0: 8507.785997473684}
# 2.0 2704.551385222222
# 3.0 3175.2459733333335
# 4.0 3623.4367573888894
# 5.0 4192.5312766666675
# 6.0 4375.607706944445
# 7.0 8507.785997473684
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 3353.015226888889, 3.0: 6065.6969658333355, 4.0: 10055.418663166667, 5.0: 15062.222011222222, 6.0: 20770.794107055557, 7.0: 46981.023474210524}
# 2.0 3353.015226888889
# 3.0 6065.6969658333355
# 4.0 10055.418663166667
# 5.0 15062.222011222222
# 6.0 20770.794107055557
# 7.0 46981.023474210524
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 7059.1648423333345, 3.0: 14114.315916222224, 4.0: 31722.130726666663, 5.0: 59080.586952499994, 6.0: 101408.24645677778, 7.0: 267451.03487747366}
# 2.0 7059.1648423333345
# 3.0 14114.315916222224
# 4.0 31722.130726666663
# 5.0 59080.586952499994
# 6.0 101408.24645677778
# 7.0 267451.03487747366
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 4
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 10050.096737222222, 3.0: 34299.22766850001, 4.0: 100391.58316194444, 5.0: 241001.687251, 6.0: 495961.32870877784, 7.0: 1525371.2249593681}
# 2.0 10050.096737222222
# 3.0 34299.22766850001
# 4.0 100391.58316194444
# 5.0 241001.687251
# 6.0 495961.32870877784
# 7.0 1525371.2249593681
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 5
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 11512.090138333333, 3.0: 76032.85452322222, 4.0: 303131.57574911107, 5.0: 892996.3329920553, 6.0: 2217474.896191389, 7.0: 8036089.171682683}
# 2.0 11512.090138333333
# 3.0 76032.85452322222
# 4.0 303131.57574911107
# 5.0 892996.3329920553
# 6.0 2217474.896191389
# 7.0 8036089.171682683
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 6
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 15137.429796000002, 3.0: 154108.29227411113, 4.0: 823240.2106218333, 5.0: 3049966.485956889, 6.0: 9122714.037389666, 7.0: 38644829.909749255}
# 2.0 15137.429796000002
# 3.0 154108.29227411113
# 4.0 823240.2106218333
# 5.0 3049966.485956889
# 6.0 9122714.037389666
# 7.0 38644829.909749255
# SELECT number_of_services, number_of_nodes, avg(execution_time)
#                 FROM qualitative_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 7
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 14787.530738444446, 3.0: 237275.68895911105, 4.0: 1615478.569077, 5.0: 7811348.222198556, 6.0: 31362885.938888114, 7.0: 135479638.33542052}
# 2.0 14787.530738444446
# 3.0 237275.68895911105
# 4.0 1615478.569077
# 5.0 7811348.222198556
# 6.0 31362885.938888114
# 7.0 135479638.33542052

# %% [markdown]
# # Window Quality Performance

# %%
mycursor = mydb.cursor()
#result_dict = {}
for n in range(3,MAX_NUMBER_OF_NODES+1):
    for w in range(1,n+1):
        query = f"""SELECT number_of_services, number_of_nodes, avg(metric_distance)
                FROM {TABLE}
                WHERE number_of_nodes = {n} AND window_size = {w}
                GROUP BY number_of_nodes, number_of_services,window_size
                ORDER BY number_of_services
            """
        mycursor.execute(query)
        print(query)
        result_dict = {}
        for row in mycursor:
            number_of_services = row[0]
            number_of_nodes = row[1]
            execution_time = row[2]
            # percentage = row[3]

            if number_of_services not in result_dict:
                result_dict[number_of_services] = execution_time
            else:
                result_dict[number_of_services].append(execution_time)
        print(result_dict)
        # Print the formatted output
        with open(f"{FOLDER}/window_quality_performance_{TABLE}_n{n}_w{w}.dat", "w") as file:
            for number_of_nodes, execution_times in result_dict.items():
                # starred = " ".join(map(str, execution_times))
                starred = execution_times
                file.write(f"{number_of_nodes} {starred}\n")
                print(number_of_nodes, starred)
# Out:
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 3 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.99428, 3.0: 0.98974, 4.0: 0.9871, 5.0: 0.98843, 6.0: 0.99797, 7.0: 0.98948}
# 2.0 0.99428
# 3.0 0.98974
# 4.0 0.9871
# 5.0 0.98843
# 6.0 0.99797
# 7.0 0.98948
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 3 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 1.0, 4.0: 0.99918, 5.0: 0.99718, 6.0: 0.99888, 7.0: 0.9963}
# 2.0 1.0
# 3.0 1.0
# 4.0 0.99918
# 5.0 0.99718
# 6.0 0.99888
# 7.0 0.9963
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 3 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 1.0, 4.0: 1.0, 5.0: 1.0, 6.0: 1.0, 7.0: 1.0}
# 2.0 1.0
# 3.0 1.0
# 4.0 1.0
# 5.0 1.0
# 6.0 1.0
# 7.0 1.0
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 4 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.99049, 3.0: 0.99348, 4.0: 0.98364, 5.0: 0.99236, 6.0: 0.99051, 7.0: 0.99104}
# 2.0 0.99049
# 3.0 0.99348
# 4.0 0.98364
# 5.0 0.99236
# 6.0 0.99051
# 7.0 0.99104
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 4 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 0.99763, 4.0: 0.99755, 5.0: 0.9975, 6.0: 0.99729, 7.0: 0.99817}
# 2.0 1.0
# 3.0 0.99763
# 4.0 0.99755
# 5.0 0.9975
# 6.0 0.99729
# 7.0 0.99817
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 4 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 0.99898, 4.0: 1.0, 5.0: 0.99894, 6.0: 1.0, 7.0: 0.99954}
# 2.0 1.0
# 3.0 0.99898
# 4.0 1.0
# 5.0 0.99894
# 6.0 1.0
# 7.0 0.99954
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 4 AND window_size = 4
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 1.0, 4.0: 1.0, 5.0: 1.0, 6.0: 1.0, 7.0: 1.0}
# 2.0 1.0
# 3.0 1.0
# 4.0 1.0
# 5.0 1.0
# 6.0 1.0
# 7.0 1.0
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.97113, 3.0: 0.97909, 4.0: 0.95939, 5.0: 0.97962, 6.0: 0.98181, 7.0: 0.98676}
# 2.0 0.97113
# 3.0 0.97909
# 4.0 0.95939
# 5.0 0.97962
# 6.0 0.98181
# 7.0 0.98676
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.98949, 3.0: 0.98135, 4.0: 0.9851, 5.0: 0.99424, 6.0: 0.99038, 7.0: 0.99467}
# 2.0 0.98949
# 3.0 0.98135
# 4.0 0.9851
# 5.0 0.99424
# 6.0 0.99038
# 7.0 0.99467
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.99821, 3.0: 0.99613, 4.0: 0.99903, 5.0: 0.99646, 6.0: 0.997, 7.0: 0.99803}
# 2.0 0.99821
# 3.0 0.99613
# 4.0 0.99903
# 5.0 0.99646
# 6.0 0.997
# 7.0 0.99803
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 4
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.99715, 3.0: 1.0, 4.0: 0.99836, 5.0: 0.99776, 6.0: 0.99887, 7.0: 0.99975}
# 2.0 0.99715
# 3.0 1.0
# 4.0 0.99836
# 5.0 0.99776
# 6.0 0.99887
# 7.0 0.99975
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 5 AND window_size = 5
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 1.0, 4.0: 1.0, 5.0: 1.0, 6.0: 1.0, 7.0: 1.0}
# 2.0 1.0
# 3.0 1.0
# 4.0 1.0
# 5.0 1.0
# 6.0 1.0
# 7.0 1.0
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.95427, 3.0: 0.96642, 4.0: 0.97464, 5.0: 0.9805, 6.0: 0.96565, 7.0: 0.98429}
# 2.0 0.95427
# 3.0 0.96642
# 4.0 0.97464
# 5.0 0.9805
# 6.0 0.96565
# 7.0 0.98429
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.9731, 3.0: 0.98617, 4.0: 0.98025, 5.0: 0.99029, 6.0: 0.99196, 7.0: 0.99707}
# 2.0 0.9731
# 3.0 0.98617
# 4.0 0.98025
# 5.0 0.99029
# 6.0 0.99196
# 7.0 0.99707
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.99112, 3.0: 0.98781, 4.0: 0.99489, 5.0: 0.99618, 6.0: 0.99677}
# 2.0 0.99112
# 3.0 0.98781
# 4.0 0.99489
# 5.0 0.99618
# 6.0 0.99677
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 4
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.99673, 3.0: 0.99235, 4.0: 0.99522, 5.0: 0.99903, 6.0: 0.99983}
# 2.0 0.99673
# 3.0 0.99235
# 4.0 0.99522
# 5.0 0.99903
# 6.0 0.99983
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 5
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.99968, 3.0: 0.99637, 4.0: 0.99839, 5.0: 0.99919, 6.0: 0.9998}
# 2.0 0.99968
# 3.0 0.99637
# 4.0 0.99839
# 5.0 0.99919
# 6.0 0.9998
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 6 AND window_size = 6
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 1.0, 4.0: 1.0, 5.0: 1.0, 6.0: 1.0, 7.0: 1.0}
# 2.0 1.0
# 3.0 1.0
# 4.0 1.0
# 5.0 1.0
# 6.0 1.0
# 7.0 1.0
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 1
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.934, 3.0: 0.94717, 4.0: 0.95858, 5.0: 0.95602, 6.0: 0.97366, 7.0: 0.97135}
# 2.0 0.934
# 3.0 0.94717
# 4.0 0.95858
# 5.0 0.95602
# 6.0 0.97366
# 7.0 0.97135
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 2
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.97042, 3.0: 0.97737, 4.0: 0.98192, 5.0: 0.9848, 6.0: 0.98577, 7.0: 0.9857}
# 2.0 0.97042
# 3.0 0.97737
# 4.0 0.98192
# 5.0 0.9848
# 6.0 0.98577
# 7.0 0.9857
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 3
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.98533, 3.0: 0.99254, 4.0: 0.99305, 5.0: 0.99356, 6.0: 0.99665, 7.0: 0.99353}
# 2.0 0.98533
# 3.0 0.99254
# 4.0 0.99305
# 5.0 0.99356
# 6.0 0.99665
# 7.0 0.99353
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 4
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.98888, 3.0: 0.9952, 4.0: 0.99404, 5.0: 0.99441, 6.0: 0.99691, 7.0: 0.99779}
# 2.0 0.98888
# 3.0 0.9952
# 4.0 0.99404
# 5.0 0.99441
# 6.0 0.99691
# 7.0 0.99779
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 5
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 0.99408, 4.0: 0.99827, 5.0: 0.99559, 6.0: 0.99796, 7.0: 0.99879}
# 2.0 1.0
# 3.0 0.99408
# 4.0 0.99827
# 5.0 0.99559
# 6.0 0.99796
# 7.0 0.99879
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 6
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 0.99791, 3.0: 0.99527, 4.0: 0.99897, 5.0: 0.99966, 6.0: 0.99992, 7.0: 0.99996}
# 2.0 0.99791
# 3.0 0.99527
# 4.0 0.99897
# 5.0 0.99966
# 6.0 0.99992
# 7.0 0.99996
# SELECT number_of_services, number_of_nodes, avg(metric_distance)
#                 FROM diff_qual_n7_s7_50_80
#                 WHERE number_of_nodes = 7 AND window_size = 7
#                 GROUP BY number_of_nodes, number_of_services,window_size
#                 ORDER BY number_of_services
#
# {2.0: 1.0, 3.0: 1.0, 4.0: 1.0, 5.0: 1.0, 6.0: 1.0, 7.0: 1.0}
# 2.0 1.0
# 3.0 1.0
# 4.0 1.0
# 5.0 1.0
# 6.0 1.0
# 7.0 1.0

# %%
mycursor = mydb.cursor()
#result_dict = {}
for n in range(2,6):
    for w in range(1,n):
        query = f"""SELECT number_of_services, number_of_nodes, avg(percentage)
                FROM pippo.mytable
                WHERE number_of_nodes = {n} AND window_size = {w}
                GROUP BY number_of_nodes, number_of_services,window_size
                ORDER BY number_of_services
            """
        mycursor.execute(query)

        result_dict = {}
        for row in mycursor:
            number_of_services = row[0]
            number_of_nodes = row[1]
            execution_time = row[2]

            if number_of_services not in result_dict:
                result_dict[number_of_services] = [execution_time]
            else:
                result_dict[number_of_services].append(execution_time)

        # Print the formatted output
        with open(f"{FOLDER}/window_percentage_performance_n{n}_w{w}.dat", "w") as file:
            for number_of_nodes, execution_times in result_dict.items():
                starred = " ".join(map(str, execution_times))
                file.write(f"{wino} {number_of_nodes} {starred}\n")
                print(number_of_nodes, starred)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mycursor = mydb.cursor()
#       2 #result_dict = {}
#       3 for n in range(2,6):
#
# File /usr/local/lib/python3.10/site-packages/mysql/connector/connection_cext.py:728, in CMySQLConnection.cursor(self, buffered, raw, prepared, cursor_class, dictionary, named_tuple)
#     726 self.handle_unread_result(prepared)
#     727 if not self.is_connected():
# --> 728     raise OperationalError("MySQL Connection not available.")
#     729 if cursor_class is not None:
#     730     if not issubclass(cursor_class, CMySQLCursor):
#
# OperationalError: MySQL Connection not available.

# %%
mydb.close()
